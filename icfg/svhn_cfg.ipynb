# %%
run train_cfggan.py --dataset SVHN --dataroot ../ --save_interval 1000 --save mod/svhn-gp0-dcganx-lamda0.1-eta0.5 --gen svhn_lr0.00025_gp1_lamda0.1_eta0.5/svhn-gp-dcganx --gptype 1 --lamda 0.1 --alpha 1
# Out:
# Setting up a new session...
# Traceback (most recent call last):
#   File "/home/zjnu/miniconda3/envs/wc_pytorch11/lib/python3.7/site-packages/urllib3/connection.py", line 170, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "/home/zjnu/miniconda3/envs/wc_pytorch11/lib/python3.7/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/home/zjnu/miniconda3/envs/wc_pytorch11/lib/python3.7/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/zjnu/miniconda3/envs/wc_pytorch11/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
# ...

# %%
from redirect import redirect_output
# %env CUDA_VISIBLE_DEVICES=5
file_dir = 'tw_lr0.00025_alpha1_eta1_epo10_t15_resnet_gp2_lamda0.1_scale0.1_jupyter'
mod = 'mod/resnet4-t15-cifar10-epo10-gp2-lamda0.1-scale0.5-eta0.25_test'
file_out = file_dir+'/'
# print(file_out)
# %env CUDA_VISABLE_DEVICES=5
with redirect_output(file_dir):
    # %run train_cfggan.py --dataset lsun_tower64 --dataroot ../LSUN/ --save_interval 1000 --lr 0.00025 --alpha 1 --cfg_eta 1 --cfg_x_epo 10 --cfg_T 15 --model resnet4 --save mod/tw-resnet-0.00025-alpha1-eta1-epo10-t15-gp2-lamda0.1-scale0.1-jupyter --gen tw_lr0.00025_alpha1_eta1_epo10_t15_resnet_gp2_lamda0.1_scale0.1_jupyter/tw64-resnet --lamda 0.1 --gptype 2 --scale 0.1
# Out:
# env: CUDA_VISIBLE_DEVICES=5
# env: CUDA_VISABLE_DEVICES=5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/wc/cfg-gan-pt-master/train_cfggan.py in <module>
#     214
#     215 if __name__ == '__main__':
# --> 216    main(sys.argv[1:])
#
# ~/Documents/wc/cfg-gan-pt-master/train_cfggan.py in main(args)
#     211    opt = parser.parse_args(args)
#     212    check_args_(opt)
# --> 213    cfggan_train(opt)
#     214
#     215 if __name__ == '__main__':
#
# ~/Documents/wc/cfg-gan-pt-master/cfggan_train.py in proc(opt)
#     111                        pin_memory=torch.cuda.is_available())
#     112
# --> 113    cfggan(opt, d_config, g_config, z_gen, loader,from_file,saved)
#     114
#     115 #----------------------------------------------------------
#
# ...

# %%
param={'group.conv0.w':1,'group.conv0.b':2}
print(param['group.conv0.w'])
print(param.get('group'+'conv0.b'))
# Out:
# 1
# None
